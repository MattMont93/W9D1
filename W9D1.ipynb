# %% [markdown]
# # Task 1 Fare la spesa al supermercato
#
# ## Algoritmo
#
# * Preparare una lista degli alimenti necessari.
#
# * Controllare in casa se alcuni prodotti sono già disponibili.
#
# * Prendere portafoglio, chiavi e borse riutilizzabili.
#
# * Raggiungere il supermercato.
#
# * Prendere un carrello o un cestino.
#
# * Cercare i prodotti seguendo la lista.
#
# * Mettere nel carrello solo ciò che serve.
#
# * Raggiungere la cassa.
#
# * Pagare la spesa.
#
# * Riporre gli acquisti nelle borse.
#
# * Tornare a casa.
#
# * Sistemare i prodotti negli scaffali o nel frigorifero.

# %% [markdown]
# # Task 2 Studiare un nuovo concetto
#
# ## Algoritmo
#
# * Cercare una fonte affidabile (libro, video, corso, documentazione).
#
# *  Leggere o guardare una prima spiegazione generale.
#
# * Annotare i punti chiave.
#
# * Cercare esempi pratici del concetto.
#
# * Provare a ripetere gli esempi da soli.
#
# * Verificare se si è capito spiegando il concetto a parole proprie.
#
# * Fare esercizi o applicazioni pratiche.
#
# * Ripassare dopo qualche ora o giorno per consolidare.

# %% [markdown]
# # Task 3 Riempire il serbatoio dell’auto
#
# ## Algoritmo
#
# * Controllare il livello del carburante sul cruscotto.
#
# * Cercare un distributore nelle vicinanze.
#
# * Parcheggiare l’auto vicino alla pompa.
#
# * Spegnere il motore.
#
# * Aprire lo sportellino del serbatoio.
#
# * Selezionare il tipo di carburante corretto.
#
# * Inserire la pistola nel serbatoio.
#
# * Premere il grilletto per avviare il rifornimento.
#
# * Attendere che il serbatoio sia pieno o raggiunga la quantità desiderata.
#
# * Riporre la pistola nella pompa.
#
# * Chiudere il serbatoio.
#
# * Pagare alla cassa o alla colonnina automatica.
#
# * Ripartire.

# %% [markdown]
# ## consegna 1

# %%
studenti = 25

# %%
print(studenti)
# Out:
# 25

# %% [markdown]
# ## consegna 2

# %%
Studenti = 25
print(Studenti)
# Out:
# 25

# %% [markdown]
# ## consegna 3

# %%
studenti_iniziali = 25

# %%
nuovi_studenti = 3

# %%
totale_studenti = studenti_iniziali + nuovi_studenti

# %%
print(totale_studenti)
# Out:
# 28

# %% [markdown]
# ## consegna 4

# %%
scuola = "Epicode"

# %%
print(scuola)
# Out:
# Epicode

# %%
x=10

# %%
print(x)
# Out:
# 10

# %%
y=x+2
print(y)
# Out:
# 12

# %%
z=y*3
print(z)
# Out:
# 36

# %% [markdown]
# # consegna 5

# %%
str1 = "Windows"
str2 = "Excel"
str3 = "Powerpoint"
str4 = "Word"

# %%
len(str1)
# Out:
# 7

# %%
len(str2)
# Out:
# 5

# %%
len(str3)
# Out:
# 10

# %%
len(str4)
# Out:
# 4

# %% [markdown]
# # Consegna 6

# %%
minuti=60*60
secondi=(minuti)*24*365
print(secondi)
# Out:
# 31536000

# %% [markdown]
# ## consegna 7

# %%
my_string = "i am studyng Python"

# %%
my_string = my_string.upper()
print(my_string)
# Out:
# I AM STUDYNG PYTHON

# %%
my_string = my_string.lower()
print(my_string)
# Out:
# i am studyng python

# %%
replaced_string = my_string.replace("python","a lot")
my_string = replaced_string
print(my_string)
# Out:
# i am studyng a lot

# %%
stripped_string = my_string.strip()
my_string = stripped_string
print(my_string)
# Out:
# i am studyng a lot

# %%
token = my_string.split()
print(token)
# Out:
# ['i', 'am', 'studyng', 'a', 'lot']

# %% [markdown]
# ## consegna 8

# %%
studenti = ["Alex", "Bob", "Cindy" , "Dan" , "Emma", "Faith", "Grace", "Henry"]
corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]

# %%
for studente,corso in zip(studenti,corsi):
    print(studente," ",corso)
# Out:
# Alex   Cybersecurity
# Bob   Data Analyst
# Cindy   Backend
# Dan   Frontend
# Emma   Data Analyst
# Faith   Backend

# %%
corsi.append("Frontend")
corsi.append("Cybersecurity")

# %%
for studente,corso in zip(studenti,corsi):
    print(studente," ",corso)
# Out:
# Alex   Cybersecurity
# Bob   Data Analyst
# Cindy   Backend
# Dan   Frontend
# Emma   Data Analyst
# Faith   Backend
# Grace   Cybersecuryty
# Henry   Frontend
