# %%
studenti = 25

# %%
print(studenti)
# Out:
# 25

# %%
Studenti = 25
print(Studenti)
# Out:
# 25

# %%
studenti_iniziali = 25

# %%
nuovi_studenti = 3

# %%
totale_studenti = studenti_iniziali + nuovi_studenti

# %%
print(totale_studenti)
# Out:
# 28

# %%
scuola = "Epicode"

# %%
print(scuola)
# Out:
# Epicode

# %%
x=10

# %%
print(x)
# Out:
# 10

# %%
y=x+2
print(y)
# Out:
# 12

# %%
z=y*3
print(z)
# Out:
# 36

# %%
str1 = "Windows"
str2 = "Excel"
str3 = "Powerpoint"
str4 = "Word"

# %%
len(str1)
# Out:
# 7

# %%
len(str2)
# Out:
# 5

# %%
len(str3)
# Out:
# 10

# %%
len(str4)
# Out:
# 4

# %% [markdown]
# # Calcolo secondi anno bisestile

# %%
minuti=60*60
secondi=(minuti)*24*365
print(secondi)
# Out:
# 31536000
